# %% [markdown]
# <a href="https://colab.research.google.com/github/xhavien/CCADMACL_EXERCISES_COM222-ML/blob/main/Exercise1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercise 1
#
# Use all feature selection methods to find the best features

# %% [markdown]
# ## Dataset Information
#
# ## Features
#
# Number of Instances: 20640
#
# Number of Attributes: 8 numeric, predictive attributes and the target
#
# Attribute Information:
#
# MedInc - median income in block group
#
# HouseAge - median house age in block group
#
# AveRooms - average number of rooms per household
#
# AveBedrms - average number of bedrooms per household
#
# Population - block group population
#
# AveOccup - average number of household members
#
# Latitude - block group latitude
#
# Longitude - block group longitude
#
# ## Target
# The target variable is the median house value for California districts, expressed in hundreds of thousands of dollars ($100,000).

# %%
from sklearn.datasets import fetch_california_housing
import pandas as pd
from sklearn.feature_selection import VarianceThreshold
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
housing = fetch_california_housing(as_frame=True)
df = pd.concat([housing.data, housing.target], axis=1)

# %%
score_list = {}

# %%
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  MedHouseVal
# ...

# %%
X = housing.data
y = housing.target

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=1)

# %%
lr_model = LinearRegression()

lr_model.fit(X_train, y_train)

y_pred = lr_model.predict(X_test)

# %%
lr_model.fit(X,y)
# Out:
# LinearRegression()

# %%
rmse = np.sqrt(np.mean((y_test - y_pred) ** 2))

print(f'Root Mean Squared Error: {rmse}')
# Out:
# Root Mean Squared Error: 0.7219777996952079

# %%
score_list = {}
score_list["Default"] = rmse

# %% [markdown]
# 1. Use any filter method to select the best features

# %%
selector = VarianceThreshold(threshold=0.2) # Variance threshold
sel = selector.fit(df) # Use the correct dataframe name 'df'
sel_index = sel.get_support()
df_fetch_california_housing_norm_vt = df.iloc[:, sel_index] # Use the correct dataframe name 'df'

# %%
df_fetch_california_housing_norm_vt
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  MedHouseVal
# ...

# %%
from sklearn.feature_selection import f_classif

threshold = 5 # the number of most relevant features
high_score_features = []
feature_scores = f_classif(df_fetch_california_housing_features, df_fetch_california_housing_target.values.ravel())[0]

# %%
from sklearn.feature_selection import f_classif

threshold = 5
high_score_features = []

feature_scores = f_classif(df_fetch_california_housing_features, df_fetch_california_housing_target.values.ravel())[0]

for score, f_name in sorted(zip(feature_scores, df_fetch_california_housing_features.columns), reverse=True)[:threshold]: # Replace df_wine_features with df_fetch_california_housing_features
    # print(f_name, score)
    high_score_features.append(f_name)


df_fetch_california_housing_fc = df_fetch_california_housing_features[high_score_features]
df_fetch_california_housing_fc.columns
# Out:
# Index(['MedInc', 'Latitude', 'Population', 'HouseAge', 'Longitude'], dtype='object')

# %%
df_fetch_california_housing_fc
# Out:
#        MedInc  Latitude  Population  HouseAge  Longitude
# 0      8.3252     37.88       322.0      41.0    -122.23
# 1      8.3014     37.86      2401.0      21.0    -122.22
# 2      7.2574     37.85       496.0      52.0    -122.24
# 3      5.6431     37.85       558.0      52.0    -122.25
# 4      3.8462     37.85       565.0      52.0    -122.25
# ...       ...       ...         ...       ...        ...
# 20635  1.5603     39.48       845.0      25.0    -121.09
# 20636  2.5568     39.49       356.0      18.0    -121.21
# 20637  1.7000     39.43      1007.0      17.0    -121.22
# 20638  1.8672     39.43       741.0      18.0    -121.32
# 20639  2.3886     39.37      1387.0      16.0    -121.24
#
# [20640 rows x 5 columns]

# %%
x = df_fetch_california_housing_fc
y = housing.target

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=1)

# %%
lr_model = LinearRegression()

lr_model.fit(X_train, y_train)

y_pred = lr_model.predict(X_test)

# %%
lr_model.fit(X,y)
# Out:
# LinearRegression()

# %%
lF = pd.DataFrame({'Actual_Price': y_test, 'Predicted Price': y_pred})

# %%
print(lF)
# Out:
#        Actual_Price  Predicted Price
# 4712          3.550         2.119432
# 2151          0.707         0.944097
# 15927         2.294         2.693965
# 82            1.125         1.693198
# 8161          2.254         2.828415
# ...             ...              ...
# 19132         3.103         2.330521
# 19573         1.748         1.465197
# 11317         1.796         1.678239
# 8500          2.186         2.070639
# 8544          2.750         1.855366
#
# [8256 rows x 2 columns]

# %%
sum_of_squared_errors = str(np.sum(np.square(lF['Actual_Price'] - lF['Predicted Price'])))
print("Residual sum of squares is : ", sum_of_squared_errors)
# Out:
# Residual sum of squares is :  4303.456043494571

# %%
r2_score = lr_model.score(X_test, y_test)

# Print the score
print(f'R2 score: {r2_score}')
# Out:
# R2 score: 0.6079387205512672

# %%
rmse = np.sqrt(np.mean((y_test - y_pred) ** 2))

# Print the RMSE
print(f'Root Mean Squared Error: {rmse}')
# Out:
# Root Mean Squared Error: 0.7219777996952079

# %%
score_list["Filter Method"] = rmse

# %% [markdown]
# 2. Use any wrapper method to select the best features

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.feature_selection import RFE


threshold = 5
model_rf = RandomForestRegressor(n_estimators=500, random_state=0, max_depth = 3)
selector = RFE(model_rf, n_features_to_select=5, step=1)

selector = selector.fit(df_fetch_california_housing_features, df_fetch_california_housing_target.values.ravel())
selector_ind = selector.get_support()
df_fetch_california_housing_rfe = df_fetch_california_housing_features.iloc[:, selector_ind]
df_fetch_california_housing_rfe.columns
# Out:
# Index(['MedInc', 'HouseAge', 'AveRooms', 'AveOccup', 'Latitude'], dtype='object')

# %%
x = df_fetch_california_housing_fc
y = housing.target

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=1)

# %%
lr_model = LinearRegression()

lr_model.fit(X_train, y_train)

y_pred = lr_model.predict(X_test)

# %%
lr_model.fit(X,y)
# Out:
# LinearRegression()

# %%
rmse = np.sqrt(np.mean((y_test - y_pred) ** 2))

# Print the RMSE
print(f'Root Mean Squared Error: {rmse}')
# Out:
# Root Mean Squared Error: 0.7219777996952079

# %%
score_list["Wrapper Method"] = rmse

# %% [markdown]
# 3. Use any embedded methood to select the best features

# %%
from sklearn.feature_selection import SelectFromModel

model_rf = RandomForestRegressor(n_estimators=500, random_state=0, max_depth = 3)
model_rf.fit(df_fetch_california_housing_features, df_fetch_california_housing_target.values.ravel())

sel_sfm = SelectFromModel(model_rf, prefit=True)
sel_sfm_index = sel_sfm.get_support()
df_fetch_california_housing_sfm = df_fetch_california_housing_features.iloc[:, sel_sfm_index]
df_fetch_california_housing_sfm.columns
# Out:
# Index(['MedInc', 'AveOccup'], dtype='object')

# %%
x = df_fetch_california_housing_fc
y = housing.target

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=1)

# %%
y_pred = model_rf.predict(X_test)

# %%
rmse = np.sqrt(np.mean((y_test - y_pred) ** 2))

print(f'Root Mean Squared Error: {rmse}')
# Out:
# Root Mean Squared Error: 0.7614661717005624

# %%
score_list["Embedded Method"] = rmse

# %% [markdown]
# Evaluation Each Method

# %%
score_list = list(score_list.items())

# %%
for alg,score in score_list:
    print(f"{alg} Score is {str(score)[:4]} ")
# Out:
# Default Score is 0.72
# Filter Method Score is 0.72
# Wrapper Method Score is 0.72
# Embedded Method Score is 0.76
